# %%
model_id = "sentence-transformers/all-MiniLM-L6-v2"
hf_token = "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"

# %%
import requests
from retry import retry

api_url = f"https://api-inference.huggingface.co/pipeline/feature-extraction/{model_id}"
headers = {"Authorization": f"Bearer {hf_token}"}

# %% [markdown]
# ### Generacion de embeddings

# %%
@retry(tries=3, delay=10)
def query(texts):
    response = requests.post(api_url, headers=headers, json={"inputs": texts})
    result = response.json()
    print(result)
    if isinstance(result, list):
      return result
    elif list(result.keys())[0] == "error":
      raise RuntimeError(
          "The model is currently loading, please re-run the query."
          )

# %%
from json_cleaner_and_converter import json_to_dataframe
df = json_to_dataframe('web-scrapping/scraper/extraction/*.json')
df["embedding"] = query(df["content"].tolist())
# Out:
# [[-0.036524586379528046, 0.0752684697508812, 0.024583466351032257, 0.00961547065526247, 0.02466585487127304, 0.09877210110425949, -0.020703932270407677, -0.003950054757297039, 0.012347975745797157, 0.018478170037269592, 0.05401242524385452, -0.0027850314509123564, -0.020499495789408684, -0.03614186495542526, 0.018398011103272438, -0.01606239378452301, -0.023429786786437035, -0.006483232602477074, -0.016796614974737167, -0.011474143713712692, -0.03718096762895584, 0.013095933943986893, -0.010470084846019745, -0.025561360642313957, 0.04945765808224678, -0.10572347790002823, 0.02245912328362465, 0.02750973217189312, -0.03634612262248993, 0.02851942554116249, 0.011938045732676983, 0.04035051539540291, -0.044626735150814056, 0.08014127612113953, 0.04465274140238762, -0.10473640263080597, -0.021513493731617928, 0.018873687833547592, 0.05764938145875931, -0.040044721215963364, 0.026437539607286453, -0.1258319616317749, -0.01939552091062069, -0.1418180763721466, -0.02508978731930256, 0.010274915024638176, 0.05082923546433449, -0.044656939804553986, -0.04878924414515495, 0.07251712679862976, -0.035159967839717865, 0.0845208391547203, 0.0016070278361439705, 0.00014566497702617198, -0.02324177883565426, -0.01718570664525032, -0.014420689083635807, 0.0364593006670475, -0.022672368213534355, -0.01037118025124073, -0.026976589113473892, 0.013509136624634266, -0.03348918259143829, -0.01821812056005001, -0.021953491494059563, 0.0404757522046566, 0.01590181514620781, 0.06624126434326172, -0.051677703857421875, -0.0006435601972043514, -0.046221159398555756, 0.0008446938009001315, -0.014109591953456402, 0.018248165026307106, -0.08010369539260864, -0.09543897211551666, 0.02257816307246685, 0.13568122684955597, 0.10211925953626633, -0.18270544707775116, 0.04097948968410492, 0.04492920637130737, -0.02459716610610485, 0.006523570511490107, -0.04171713814139366, -0.015285512432456017, -0.023829583078622818, 0.0025733388029038906, 0.09418926388025284, 0.04499093070626259, 0.07034847885370255, -0.057692497968673706, -0.04402228817343712, -0.018801109865307808, 0.07316618412733078, -0.015775935724377632, -0.038411714136600494, -0.06802535802125931, 0.015887632966041565, -0.03296066075563431, 0.02558230049908161, 0.07354927808046341, -0.0041291615925729275, -0.05526319891214371, -0.018015515059232712, 0.00145142141263932, 0.056857090443372726, -0.006825172808021307, 0.005577712319791317, -0.00391880189999938, -0.06642461568117142, 0.03339088708162308, -0.04972949996590614, -0.07693496346473694, 0.02630196325480938, -0.05414764955639839, -0.023507237434387207, -0.045554596930742264, 0.025548521429300308, 0.017862636595964432, 0.05912848189473152, 0.004119896795600653, -0.07405315339565277, -0.081358402967453, 0.016053015366196632, 0.002587429713457823, -0.03061135858297348, 4.080501988875053e-33, 0.0934586301445961, 0.10154035687446594, 0.01616279035806656, -0.017397716641426086, -0.056077275425195694, 0.01392717007547617, -0.020263655111193657, -0.006618590094149113, -0.04303153231739998, 0.08277738094329834, -0.06586629152297974, -0.014624835923314095, -0.02990109659731388, -0.0009164747898466885, 0.06290817260742188, 0.04411924630403519, -0.061246346682310104, 0.08724766969680786, 0.01576347090303898, 0.055294692516326904, 0.01749146170914173, -0.002751474268734455, 0.06392978131771088, -0.028549309819936752, 0.07704159617424011, 0.01796429418027401, -0.004876196850091219, -0.04167713597416878, 0.013887994922697544, 0.05538257211446762, 0.013757240027189255, 0.05376322567462921, 0.061699654906988144, -0.06495021283626556, -0.07030759006738663, -0.007211735472083092, -0.040671348571777344, 0.041639260947704315, -0.009850970469415188, -0.018848063424229622, 0.07519200444221497, 0.014582042582333088, 0.05140449106693268, 0.07671307772397995, -0.02722838893532753, 0.04806312546133995, -0.0026106552686542273, 0.004593934863805771, 0.031488802284002304, 0.01954128034412861, -0.03986702859401703, -0.022541701793670654, -0.033986736088991165, -0.01407740637660 ...

# %%
df
# Out:
#                                                 title  \
# 0   Capitalizing on Vietnam's Healthy and Sustaina...
# 1   Russian Orthodox priests face persecution from...
# 2                                      HOME - Archyde
# 3   Samia uses Magufuli-style tactics on critics o...
# 4   Saudi Arabia appoints first Palestinian envoy ...
# ..                                                ...
# 92  Nursing Detroit Training Center Opens at Durfe...
# 93  Worcester’s Indian Lake closing Tuesday for al...
# 94  GOP debate: Where each candidate stands on the...
# 95  Tinubu, Mbah meet over Enugu’s development – T...
# 96  Nothing Can Be Worse Than Economy President Ti...
#
#                                               content  \
# 0   The Social Security Agreement between Vietnam ...
# 1   Partly cloudy. Low 76F. Winds light and variab...
# 2   The independent manufacturer ZH Studio, in par...
# 3   Tanzanian President Samia Suluhu Hassan. PHOTO...
# 4   I accept the JTA Privacy Policy. By submitting...
# ..                                                ...
# 92  Designed to meet demand in the health care sec...
# 93  Update: Due to rain, the lake will be reopened...
# 94  The Republican National Committee wants qualif...
# 95  From Juliana Taiwo-Obalonye, Abuja President B...
# 96  Former APC National Chairman Oshiomhole, Slams...
#
#                                             embedding
# 0   [-0.036524586379528046, 0.0752684697508812, 0....
# 1   [0.0486292764544487, 0.025456130504608154, -0....
# 2   [-0.11916355043649673, 0.041927848011255264, -...
# 3   [-0.09568692743778229, 0.043381985276937485, -...
# 4   [0.0034141235519200563, 0.01724512316286564, 0...
# ..                                                ...
# 92  [-0.08147545158863068, -0.12105432152748108, -...
# 93  [-0.04935750737786293, 0.023076243698596954, 0...
# 94  [-0.00406273640692234, -0.0035951111931353807,...
# 95  [0.007244040723890066, -0.007231647614389658, ...
# 96  [-0.022682638838887215, 0.013708043843507767, ...
#
# [97 rows x 3 columns]

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
858728170395, -0.056436650454998016, -0.0670805349946022, 0.036425378173589706, 0.008192718029022217, 0.010760517790913582, 0.003753677476197481, 0.0007179306703619659, 0.03064814768731594, 0.022156523540616035, 0.1224614754319191, 0.06034449487924576, 0.020324068143963814, 0.07312902808189392, -0.02520366758108139, -0.016922684386372566, 0.04157497361302376, -0.04484611377120018, 0.03717176616191864, 0.008394269272685051, -0.07862313836812973, 0.005044503137469292, 0.05019335076212883, -0.10481453686952591, -0.004942822270095348, -0.06145747750997543, -0.03689224272966385, 0.04306373745203018, -0.03571688011288643, -0.02295575477182865, -0.032939277589321136, 0.04495451971888542, 0.08723004907369614, -0.018456680700182915, -0.031215695664286613, 0.02055414579808712, -0.02723287232220173, 0.0536971241235733, 0.07230342924594879, -0.14214761555194855, -0.05153118073940277, ...

# %%
# Convertir cada embedding de la columna 'embedding' a un array de NumPy
df["embedding"] = df["embedding"].apply(lambda x: np.array(x))

# Ahora puedes convertir toda la columna en un array 2D de NumPy
news_embeddings_np = np.array(df["embedding"].tolist())  # Asegura que sea un array 2D de floats

query_embedding_np = np.array(reference_embedding)

# Calcular la similitud del coseno entre la consulta y todas las noticias
similarities = cosine_similarity([query_embedding_np], news_embeddings_np)[0]

# %%
top_k = 10  # Número de resultados que quieres obtener

# Obtener los índices de los top_k resultados más similares
top_k_indices = similarities.argsort()[-top_k:][::-1]  # Orden de mayor a menor

# Mostrar los índices y las similitudes correspondientes
for idx in top_k_indices:
    print(f"Noticia {idx} - Similaridad: {similarities[idx]}")

# Si tienes una lista de noticias, puedes recuperar las noticias más similares así:
top_k_noticias = [df["title"][idx] for idx in top_k_indices]
# Out:
# Noticia 4 - Similaridad: 0.5549048803763158
# Noticia 60 - Similaridad: 0.5416101985831872
# Noticia 70 - Similaridad: 0.4708427892441013
# Noticia 33 - Similaridad: 0.43841085565541915
# Noticia 89 - Similaridad: 0.41637760061432905
# Noticia 12 - Similaridad: 0.40488993661805034
# Noticia 15 - Similaridad: 0.35260824088268383
# Noticia 24 - Similaridad: 0.3275227377564065
# Noticia 3 - Similaridad: 0.3265500193758707
# Noticia 28 - Similaridad: 0.3045268569638364

# %%
top_k_noticias
# Out:
# ['Saudi Arabia appoints first Palestinian envoy as Saudi-Israel normalization talks continue - Jewish Telegraphic Agency',
#  "Iran announces FM's visit to Saudi Arabia in near future | Al Mayadeen English",
#  'Palestinians Complain Biden Admin Has Done Nothing For Them | Frontpage Mag',
#  'Syrian Civilians Struggle between Deadly Israeli Air Strikes and Equally Deadly US Sanctions | HUMAN WRONGS WATCH',
#  'How Rabaa and its symbol changed Turkish-Egyptian relations | Middle East Eye',
#  'US breaking pledge to help prominent political prisoner in Egypt, family says | Middle East Eye',
#  'Niger Says 17 Soldiers Killed in Ambush - allAfrica.com',
#  'Two years after Taliban takeover, many Afghans who helped Canada’s military remain in limbo - The Globe and Mail',
#  'Samia uses Magufuli-style tactics on critics of controversial Dar port deal - The East African',
#  'Caretaker PM vows to ensure protection of minorities in Pakistan']
